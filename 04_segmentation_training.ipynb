# %%
#!pip install git+https://github.com/qubvel/segmentation_models
#!pip install -U albumentations
#!pip install imgaug
#!pip install pydot
#!pip install graphviz 
#install graphviz https://graphviz.org/download/
#!pip install -U typing_extensions
#!sudo apt-get update
#!sudo apt install graphviz -y
# Out:
# Collecting git+https://github.com/qubvel/segmentation_models
#   Cloning https://github.com/qubvel/segmentation_models to /tmp/pip-req-build-mkt6mz8z
#   Running command git clone --filter=blob:none --quiet https://github.com/qubvel/segmentation_models /tmp/pip-req-build-mkt6mz8z
#   Resolved https://github.com/qubvel/segmentation_models to commit e951c6747f75fa9e7240816d1c79dd2e66813123
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: keras_applications<=1.0.8,>=1.0.7 in /home/jack155861/.local/lib/python3.8/site-packages (from segmentation-models==1.0.1) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /home/jack155861/.local/lib/python3.8/site-packages (from segmentation-models==1.0.1) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /home/jack155861/.local/lib/python3.8/site-packages (from segmentation-models==1.0.1) (1.0.0)
# Requirement already satisfied: scikit-image in /home/jack155861/.local/lib/python3.8/site-packages (from efficientnet==1.0.0->segmentation-models==1.0.1) (0.18.2)
# Requirement already satisfied: h5py in /home/jack155861/.local/lib/python3.8/site-packages (from keras_applications<=1.0.8,>=1.0.7->segmentation-models==1.0.1) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /home/jack155861/.local/lib/python3.8/site-packages (from keras_applications<=1.0.8,>=1.0.7->segmentation-models==1.0.1) (1.21.6)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2.6.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (9.2.0)
# Requirement already satisfied: imageio>=2.3.0 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2.22.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2021.7.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (3.5.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (1.4.1)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (1.4.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (7.0.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (4.34.4)
# Requirement already satisfied: six>=1.5 in /home/jack155861/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (1.15.0)
# Requirement already satisfied: typing-extensions in /home/jack155861/.local/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (4.4.0)
# Requirement already satisfied: setuptools in /home/jack155861/.local/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from setuptools-scm>=4->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2.0.1)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
#     for segment in segments:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1283, in render
#     renderable = rich_cast(renderable)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/local/bin/pip", line 8, in <module>
#     sys.exit(main())
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 190, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 236, in pip_self_version_check
#     logger.warning("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1458, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 954, in handle
#     self.emit(record)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.2.2', new='22.3.1'),)
# Requirement already satisfied: albumentations in /home/jack155861/.local/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.11.1 in /home/jack155861/.local/lib/python3.8/site-packages (from albumentations) (1.21.6)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /home/jack155861/.local/lib/python3.8/site-packages (from albumentations) (4.5.3.56)
# Requirement already satisfied: scikit-image>=0.16.1 in /home/jack155861/.local/lib/python3.8/site-packages (from albumentations) (0.18.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from albumentations) (1.4.1)
# Requirement already satisfied: qudida>=0.0.4 in /home/jack155861/.local/lib/python3.8/site-packages (from albumentations) (0.0.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from albumentations) (6.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from qudida>=0.0.4->albumentations) (0.24.2)
# Requirement already satisfied: typing-extensions in /home/jack155861/.local/lib/python3.8/site-packages (from qudida>=0.0.4->albumentations) (4.4.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations) (3.5.0)
# Requirement already satisfied: imageio>=2.3.0 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations) (2.22.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (4.34.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (7.0.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.1.0)
# Requirement already satisfied: six>=1.5 in /home/jack155861/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (1.15.0)
# Requirement already satisfied: setuptools in /home/jack155861/.local/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from setuptools-scm>=4->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (2.0.1)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
#     for segment in segments:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1283, in render
#     renderable = rich_cast(renderable)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/local/bin/pip", line 8, in <module>
#     sys.exit(main())
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 190, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 236, in pip_self_version_check
#     logger.warning("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1458, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 954, in handle
#     self.emit(record)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.2.2', new='22.3.1'),)
# Requirement already satisfied: imgaug in /home/jack155861/.local/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from imgaug) (3.5.0)
# Requirement already satisfied: numpy>=1.15 in /home/jack155861/.local/lib/python3.8/site-packages (from imgaug) (1.21.6)
# Requirement already satisfied: scikit-image>=0.14.2 in /home/jack155861/.local/lib/python3.8/site-packages (from imgaug) (0.18.2)
# Requirement already satisfied: imageio in /home/jack155861/.local/lib/python3.8/site-packages (from imgaug) (2.22.2)
# Requirement already satisfied: six in /home/jack155861/.local/lib/python3.8/site-packages (from imgaug) (1.15.0)
# Requirement already satisfied: opencv-python in /home/jack155861/.local/lib/python3.8/site-packages (from imgaug) (4.5.2.54)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from imgaug) (1.4.1)
# Requirement already satisfied: Shapely in /home/jack155861/.local/lib/python3.8/site-packages (from imgaug) (1.7.1)
# Requirement already satisfied: Pillow in /home/jack155861/.local/lib/python3.8/site-packages (from imgaug) (9.2.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14.2->imgaug) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/jack155861/.local/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (2021.7.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug) (7.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: setuptools in /home/jack155861/.local/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib->imgaug) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from setuptools-scm>=4->matplotlib->imgaug) (2.0.1)
# Requirement already satisfied: typing-extensions in /home/jack155861/.local/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib->imgaug) (4.4.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
#     for segment in segments:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1283, in render
#     renderable = rich_cast(renderable)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/local/bin/pip", line 8, in <module>
#     sys.exit(main())
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 190, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 236, in pip_self_version_check
#     logger.warning("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1458, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 954, in handle
#     self.emit(record)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.2.2', new='22.3.1'),)
# Requirement already satisfied: pydot in /home/jack155861/.local/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.8/dist-packages (from pydot) (3.0.9)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
#     for segment in segments:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1283, in render
#     renderable = rich_cast(renderable)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/local/bin/pip", line 8, in <module>
#     sys.exit(main())
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 190, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 236, in pip_self_version_check
#     logger.warning("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1458, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 954, in handle
#     self.emit(record)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.2.2', new='22.3.1'),)
# Requirement already satisfied: graphviz in /home/jack155861/.local/lib/python3.8/site-packages (0.17)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
#     for segment in segments:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1283, in render
#     renderable = rich_cast(renderable)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/local/bin/pip", line 8, in <module>
#     sys.exit(main())
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 190, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 236, in pip_self_version_check
#     logger.warning("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1458, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 954, in handle
#     self.emit(record)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.2.2', new='22.3.1'),)
# Requirement already satisfied: typing_extensions in /home/jack155861/.local/lib/python3.8/site-packages (4.4.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
#     for segment in segments:
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/console.py", line 1283, in render
#     renderable = rich_cast(renderable)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/local/bin/pip", line 8, in <module>
#     sys.exit(main())
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 190, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/self_outdated_check.py", line 236, in pip_self_version_check
#     logger.warning("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1458, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 954, in handle
#     self.emit(record)
#   File "/home/jack155861/.local/lib/python3.8/site-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.2.2', new='22.3.1'),)
# Get:1 http://archive.ubuntu.com/ubuntu focal InRelease [265 kB]
# Get:2 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2315 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [177 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 Packages [11.3 MB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [1714 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [27.5 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [965 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/restricted amd64 Packages [33.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 Packages [1275 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [2786 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [1834 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [30.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [55.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [27.5 kB]
# Fetched 24.4 MB in 5s (5168 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core fonts-liberation libann0
#   libcairo2 libcdt5 libcgraph6 libdatrie1 libfontconfig1 libfreetype6
#   libfribidi0 libgd3 libgraphite2-3 libgts-0.7-5 libgts-bin libgvc6 libgvpr2
#   libharfbuzz0b libice6 libjbig0 liblab-gamut1 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpathplan4 libpixman-1-0 libpng16-16
#   libsm6 libthai-data libthai0 libtiff5 libwebp6 libxaw7 libxcb-render0
#   libxcb-shm0 libxmu6 libxpm4 libxrender1 libxt6 x11-common
# Suggested packages:
#   gsfonts graphviz-doc libgd-tools
# The following NEW packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core fonts-liberation graphviz
#   libann0 libcairo2 libcdt5 libcgraph6 libdatrie1 libfontconfig1 libfreetype6
#   libfribidi0 libgd3 libgraphite2-3 libgts-0.7-5 libgts-bin libgvc6 libgvpr2
#   libharfbuzz0b libice6 libjbig0 liblab-gamut1 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpathplan4 libpixman-1-0 libpng16-16
#   libsm6 libthai-data libthai0 libtiff5 libwebp6 libxaw7 libxcb-render0
#   libxcb-shm0 libxmu6 libxpm4 libxrender1 libxt6 x11-common
# 0 upgraded, 42 newly installed, 0 to remove and 50 not upgraded.
# Need to get 7292 kB of archives.
# After this operation, 24.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libfribidi0 amd64 1.0.8-2ubuntu0.1 [24.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libpng16-16 amd64 1.6.37-2 [179 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libfreetype6 amd64 2.10.1-2ubuntu0.2 [341 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-dejavu-core all 2.37-1 [1041 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-liberation all 1:1.07.4-11 [822 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 fontconfig-config all 2.13.1-2ubuntu3 [28.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontconfig1 amd64 2.13.1-2ubuntu3 [114 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 fontconfig amd64 2.13.1-2ubuntu3 [171 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 libann0 amd64 1.1.2+doc-7build1 [26.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcdt5 amd64 2.42.2-3build2 [18.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcgraph6 amd64 2.42.2-3build2 [41.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 libjbig0 amd64 2.1-3.1build1 [26.7 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwebp6 amd64 0.6.1-2ubuntu0.20.04.1 [185 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libtiff5 amd64 4.1.0+git191117-2ubuntu0.20.04.6 [163 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libxpm4 amd64 1:3.5.12-1 [34.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgd3 amd64 2.2.5-5.2ubuntu2.1 [118 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgts-0.7-5 amd64 0.7.6+darcs121130-4 [150 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpixman-1-0 amd64 0.38.4-0ubuntu2.1 [227 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-render0 amd64 1.14-2 [14.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shm0 amd64 1.14-2 [5584 B]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrender1 amd64 1:0.9.10-1 [18.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo2 amd64 1.16.0-4ubuntu1 [583 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 libgraphite2-3 amd64 1.3.13-11build1 [73.5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libharfbuzz0b amd64 2.6.4-1ubuntu4.2 [391 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 libthai-data all 0.1.28-3 [134 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libdatrie1 amd64 0.2.12-3 [18.7 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libthai0 amd64 0.1.28-3 [18.1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 libpango-1.0-0 amd64 1.44.7-2ubuntu4 [162 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangoft2-1.0-0 amd64 1.44.7-2ubuntu4 [34.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangocairo-1.0-0 amd64 1.44.7-2ubuntu4 [24.8 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpathplan4 amd64 2.42.2-3build2 [21.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgvc6 amd64 2.42.2-3build2 [647 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgvpr2 amd64 2.42.2-3build2 [167 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/universe amd64 liblab-gamut1 amd64 2.42.2-3build2 [177 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-common all 1:7.7+19ubuntu14 [22.3 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal/main amd64 libice6 amd64 2:1.0.10-0ubuntu1 [41.0 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal/main amd64 libsm6 amd64 2:1.2.3-1 [16.1 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/main amd64 libxt6 amd64 1:1.1.5-1 [160 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmu6 amd64 2:1.1.3-0ubuntu1 [45.8 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libxaw7 amd64 2:1.0.13-1 [173 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/universe amd64 graphviz amd64 2.42.2-3build2 [590 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgts-bin amd64 0.7.6+darcs121130-4 [41.3 kB]
# Fetched 7292 kB in 7s (1086 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 42.)
# debconf: falling back to frontend: Readline
# Extracting templates from packages: 100%
#
# 78Selecting previously unselected package libfribidi0:amd64.
# (Reading database ... 45906 files and directories currently installed.)
# Preparing to unpack .../00-libfribidi0_1.0.8-2ubuntu0.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libfribidi0:amd64 (1.0.8-2ubuntu0.1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libpng16-16:amd64.
# Preparing to unpack .../01-libpng16-16_1.6.37-2_amd64.deb ...
# Unpacking libpng16-16:amd64 (1.6.37-2) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package libfreetype6:amd64.
# Preparing to unpack .../02-libfreetype6_2.10.1-2ubuntu0.2_amd64.deb ...
# Unpacking libfreetype6:amd64 (2.10.1-2ubuntu0.2) ...
# 7Progress: [  4%] [##........................................................] 8Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../03-fonts-dejavu-core_2.37-1_all.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-liberation.
# Preparing to unpack .../04-fonts-liberation_1%3a1.07.4-11_all.deb ...
# 7Progress: [  5%] [###.......................................................] 8Unpacking fonts-liberation (1:1.07.4-11) ...
# Selecting previously unselected package fontconfig-config.
# Preparing to unpack .../05-fontconfig-config_2.13.1-2ubuntu3_all.deb ...
# 7Progress: [  7%] [###.......................................................] 8Unpacking fontconfig-config (2.13.1-2ubuntu3) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libfontconfig1:amd64.
# Preparing to unpack .../06-libfontconfig1_2.13.1-2ubuntu3_amd64.deb ...
# Unpacking libfontconfig1:amd64 (2.13.1-2ubuntu3) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package fontconfig.
# Preparing to unpack .../07-fontconfig_2.13.1-2ubuntu3_amd64.deb ...
# Unpacking fontconfig (2.13.1-2ubuntu3) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libann0.
# Preparing to unpack .../08-libann0_1.1.2+doc-7build1_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libann0 (1.1.2+doc-7build1) ...
# Selecting previously unselected package libcdt5:amd64.
# Preparing to unpack .../09-libcdt5_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libcdt5:amd64 (2.42.2-3build2) ...
# Selecting previously unselected package libcgraph6:amd64.
# Preparing to unpack .../10-libcgraph6_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libcgraph6:amd64 (2.42.2-3build2) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../11-libjbig0_2.1-3.1build1_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1build1) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libwebp6:amd64.
# Preparing to unpack .../12-libwebp6_0.6.1-2ubuntu0.20.04.1_amd64.deb ...
# Unpacking libwebp6:amd64 (0.6.1-2ubuntu0.20.04.1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../13-libtiff5_4.1.0+git191117-2ubuntu0.20.04.6_amd64.deb ...
# Unpacking libtiff5:amd64 (4.1.0+git191117-2ubuntu0.20.04.6) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libxpm4:amd64.
# Preparing to unpack .../14-libxpm4_1%3a3.5.12-1_amd64.deb ...
# 7Progress: [ 17%] [#########.................................................] 8Unpacking libxpm4:amd64 (1:3.5.12-1) ...
# Selecting previously unselected package libgd3:amd64.
# Preparing to unpack .../15-libgd3_2.2.5-5.2ubuntu2.1_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libgd3:amd64 (2.2.5-5.2ubuntu2.1) ...
# Selecting previously unselected package libgts-0.7-5:amd64.
# Preparing to unpack .../16-libgts-0.7-5_0.7.6+darcs121130-4_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libgts-0.7-5:amd64 (0.7.6+darcs121130-4) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../17-libpixman-1-0_0.38.4-0ubuntu2.1_amd64.deb ...
# Unpacking libpixman-1-0:amd64 (0.38.4-0ubuntu2.1) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../18-libxcb-render0_1.14-2_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.14-2) ...
# 7Progress: [ 22%] [#############.............................................] 8Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../19-libxcb-shm0_1.14-2_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libxcb-shm0:amd64 (1.14-2) ...
# Selecting previously unselected package libxrender1:amd64.
# Preparing to unpack .../20-libxrender1_1%3a0.9.10-1_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking libxrender1:amd64 (1:0.9.10-1) ...
# Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../21-libcairo2_1.16.0-4ubuntu1_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking libcairo2:amd64 (1.16.0-4ubuntu1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../22-libgraphite2-3_1.3.13-11build1_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.13-11build1) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../23-libharfbuzz0b_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (2.6.4-1ubuntu4.2) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libthai-data.
# Preparing to unpack .../24-libthai-data_0.1.28-3_all.deb ...
# Unpacking libthai-data (0.1.28-3) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../25-libdatrie1_0.2.12-3_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libdatrie1:amd64 (0.2.12-3) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../26-libthai0_0.1.28-3_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libthai0:amd64 (0.1.28-3) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../27-libpango-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# 7Progress: [ 33%] [##################........................................] 8Unpacking libpango-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../28-libpangoft2-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking libpangoft2-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../29-libpangocairo-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 36%] [####################......................................] 8Selecting previously unselected package libpathplan4:amd64.
# Preparing to unpack .../30-libpathplan4_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libpathplan4:amd64 (2.42.2-3build2) ...
# Selecting previously unselected package libgvc6.
# Preparing to unpack .../31-libgvc6_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libgvc6 (2.42.2-3build2) ...
# Selecting previously unselected package libgvpr2:amd64.
# Preparing to unpack .../32-libgvpr2_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libgvpr2:amd64 (2.42.2-3build2) ...
# 7Progress: [ 39%] [######################....................................] 8Selecting previously unselected package liblab-gamut1:amd64.
# Preparing to unpack .../33-liblab-gamut1_2.42.2-3build2_amd64.deb ...
# Unpacking liblab-gamut1:amd64 (2.42.2-3build2) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package x11-common.
# Preparing to unpack .../34-x11-common_1%3a7.7+19ubuntu14_all.deb ...
# dpkg-query: no packages found matching nux-tools
# Unpacking x11-common (1:7.7+19ubuntu14) ...
# 7Progress: [ 41%] [########################..................................] 8Selecting previously unselected package libice6:amd64.
# Preparing to unpack .../35-libice6_2%3a1.0.10-0ubuntu1_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libice6:amd64 (2:1.0.10-0ubuntu1) ...
# Selecting previously unselected package libsm6:amd64.
# Preparing to unpack .../36-libsm6_2%3a1.2.3-1_amd64.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking libsm6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../37-libxt6_1%3a1.1.5-1_amd64.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking libxt6:amd64 (1:1.1.5-1) ...
# Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../38-libxmu6_2%3a1.1.3-0ubuntu1_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libxmu6:amd64 (2:1.1.3-0ubuntu1) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../39-libxaw7_2%3a1.0.13-1_amd64.deb ...
# Unpacking libxaw7:amd64 (2:1.0.13-1) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package graphviz.
# Preparing to unpack .../40-graphviz_2.42.2-3build2_amd64.deb ...
# Unpacking graphviz (2.42.2-3build2) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package libgts-bin.
# Preparing to unpack .../41-libgts-bin_0.7.6+darcs121130-4_amd64.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking libgts-bin (0.7.6+darcs121130-4) ...
# Setting up libgraphite2-3:amd64 (1.3.13-11build1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libpixman-1-0:amd64 (0.38.4-0ubuntu2.1) ...
# 7Progress: [ 51%] [#############################.............................] 87Progress: [ 52%] [##############################............................] 8Setting up libxpm4:amd64 (1:3.5.12-1) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libxrender1:amd64 (1:0.9.10-1) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libdatrie1:amd64 (0.2.12-3) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up libxcb-render0:amd64 (1.14-2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up liblab-gamut1:amd64 (2.42.2-3build2) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up x11-common (1:7.7+19ubuntu14) ...
# 7Progress: [ 59%] [#################################.........................] 8debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# 7Progress: [ 59%] [##################################........................] 8Setting up libxcb-shm0:amd64 (1.14-2) ...
# 7Progress: [ 60%] [###################################.......................] 8Setting up libjbig0:amd64 (2.1-3.1build1) ...
# 7Progress: [ 62%] [###################################.......................] 8Setting up libgts-0.7-5:amd64 (0.7.6+darcs121130-4) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libpathplan4:amd64 (2.42.2-3build2) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libann0 (1.1.2+doc-7build1) ...
# 7Progress: [ 64%] [#####################################.....................] 87Progress: [ 65%] [#####################################.....................] 8Setting up libfribidi0:amd64 (1.0.8-2ubuntu0.1) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libpng16-16:amd64 (1.6.37-2) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libwebp6:amd64 (0.6.1-2ubuntu0.20.04.1) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up fonts-dejavu-core (2.37-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up fonts-liberation (1:1.07.4-11) ...
# 7Progress: [ 70%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 8Setting up libthai-data (0.1.28-3) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libcdt5:amd64 (2.42.2-3build2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libcgraph6:amd64 (2.42.2-3build2) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libtiff5:amd64 (4.1.0+git191117-2ubuntu0.20.04.6) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libgts-bin (0.7.6+darcs121130-4) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libice6:amd64 (2:1.0.10-0ubuntu1) ...
# 7Progress: [ 78%] [############################################..............] 87Progress: [ 78%] [#############################################.............] 8Setting up fontconfig-config (2.13.1-2ubuntu3) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libthai0:amd64 (0.1.28-3) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libfreetype6:amd64 (2.10.1-2ubuntu0.2) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libgvpr2:amd64 (2.42.2-3build2) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libharfbuzz0b:amd64 (2.6.4-1ubuntu4.2) ...
# 7Progress: [ 83%] [################################################..........] 87Progress: [ 84%] [################################################..........] 8Setting up libfontconfig1:amd64 (2.13.1-2ubuntu3) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libsm6:amd64 (2:1.2.3-1) ...
# 7Progress: [ 86%] [##################################################........] 8Setting up fontconfig (2.13.1-2ubuntu3) ...
# Regenerating fonts cache... done.
# 7Progress: [ 88%] [##################################################........] 8Setting up libpango-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libcairo2:amd64 (1.16.0-4ubuntu1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libgd3:amd64 (2.2.5-5.2ubuntu2.1) ...
# 7Progress: [ 91%] [####################################################......] 87Progress: [ 91%] [####################################################......] 8Setting up libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libpangoft2-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libpangocairo-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libxmu6:amd64 (2:1.1.3-0ubuntu1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libxaw7:amd64 (2:1.0.13-1) ...
# 7Progress: [ 96%] [#######################################################...] 87Progress: [ 97%] [########################################################..] 8Setting up libgvc6 (2.42.2-3build2) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up graphviz (2.42.2-3build2) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for systemd (245.4-4ubuntu3.17) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#
# 78

# %%
import segmentation_models as sm
import os, cv2
from tensorflow import keras
from tensorflow.keras.utils import plot_model
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
from random import randint
# Out:
# 2022-11-18 19:33:24.434562: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-18 19:33:26.094454: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-18 19:33:32.020487: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-11-18 19:33:32.020620: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-11-18 19:33:32.020628: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/jack155861/.local/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (5.0.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# Segmentation Models: using `keras` framework.

# %% [markdown]
# # Loading dataset

# %%
DATA_DIR = './03_unet_image'
x_train_dir = os.path.join(DATA_DIR, 'image/train')
y_train_dir = os.path.join(DATA_DIR, 'mask/train')
x_valid_dir = os.path.join(DATA_DIR, 'image/test')
y_valid_dir = os.path.join(DATA_DIR, 'mask/test')

# %%
# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    CLASSES = ['papaya']
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
            data_choose=False, 
    ):
        if(data_choose==False):
            self.ids = os.listdir(images_dir)
        else:
            self.ids = sum([[x+"_"+y+".jpg" for y in [str(randint(0, 31)).rjust(2,'0') for i in range(10)]] for x in list(np.unique([x.split("_")[0] for x in os.listdir(images_dir)]))], [])
        
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        if len(np.unique(mask))>2: # 我自己加的
            mask[mask>127] = 255
            mask[mask<=127] = 0
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# %%
dataset = Dataset(x_train_dir, y_train_dir, classes=['papaya'])

image, mask = dataset[1] # get some sample
visualize(
    image=image, 
    mask=mask[..., 0].squeeze()
)

# %% [markdown]
# # Augmentations

# %%
def get_training_augmentation():
    
    def round_clip_0_1(x, **kwargs):
        return x.round().clip(0, 1)

    train_transform = [

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=320, min_width=320, always_apply=True, border_mode=0),
        #A.RandomCrop(height=680, width=680, always_apply=True),

        A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.IAASharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['papaya'], augmentation=get_training_augmentation())

image, mask = dataset[1] # get some sample
visualize(
    image=image, 
    mask=mask[..., 0].squeeze()
)
# Out:
# /home/jack155861/.local/lib/python3.8/site-packages/albumentations/imgaug/transforms.py:261: FutureWarning: IAAAdditiveGaussianNoise is deprecated. Please use GaussNoise instead
#   warnings.warn("IAAAdditiveGaussianNoise is deprecated. Please use GaussNoise instead", FutureWarning)
# /home/jack155861/.local/lib/python3.8/site-packages/albumentations/imgaug/transforms.py:384: FutureWarning: This IAAPerspective is deprecated. Please use Perspective instead
#   warnings.warn("This IAAPerspective is deprecated. Please use Perspective instead", FutureWarning)
# /home/jack155861/.local/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:1149: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# /home/jack155861/.local/lib/python3.8/site-packages/albumentations/imgaug/transforms.py:231: FutureWarning: IAASharpen is deprecated. Please use Sharpen instead
#   warnings.warn("IAASharpen is deprecated. Please use Sharpen instead", FutureWarning)
# /home/jack155861/.local/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:1175: FutureWarning: RandomContrast has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(

# %% [markdown]
# # Segmentation model parameters

# %%
# define network parameters
os.environ["SM_FRAMEWORK"] = "tf.keras"
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'
BACKBONE = 'resnet18'
BATCH_SIZE = 16
CLASSES = ['papaya']
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1) 
activation = 'sigmoid' if n_classes == 1 else 'softmax'
LR = 0.0001
EPOCHS = 100
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# create model
model = sm.Unet(BACKBONE, 
                classes=n_classes, activation=activation, input_shape=(320, 640, 3), 
                encoder_weights='imagenet')
plot_model(model, to_file=  'unet_model.png', show_shapes=True)
model.summary()

# define optomizer
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)
# Out:
# 2022-11-18 19:34:21.714342: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-18 19:34:23.668516: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:222] Using CUDA malloc Async allocator for GPU: 0
# 2022-11-18 19:34:23.668751: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30975 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:1c:00.0, compute capability: 7.0
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 320, 640, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 320, 640, 3)  9           ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 326, 646, 3)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 160, 320, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 160, 320, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 160, 320, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 162, 322, 64  0          ['relu0[0][0]']
#  D)                             )
#
#  pooling0 (MaxPooling2D)        (None, 80, 160, 64)  0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 80, 160, 64)  256        ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 80, 160, 64)  0          ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 82, 162, 64)  0          ['stage1_unit1_relu1[0][0]']
#  D)
#
#  stage1_unit1_conv1 (Conv2D)    (None, 80, 160, 64)  36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 80, 160, 64)  256        ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 80, 160, 64)  0          ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 82, 162, 64)  0          ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 80, 160, 64)  36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 80, 160, 64)  4096        ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 80, 160, 64)  0           ['stage1_unit1_conv2[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 80, 160, 64)  256        ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 80, 160, 64)  0          ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 82, 162, 64)  0          ['stage1_unit2_relu1[0][0]']
#  D)
#
#  stage1_unit2_conv1 (Conv2D)    (None, 80, 160, 64)  36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 80, 160, 64)  256        ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 80, 160, 64)  0          ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 82, 162, 64)  0          ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 80, 160, 64)  36864       ['zero_padding2d_5[0][0]']
#
#  add_1 (Add)                    (None, 80, 160, 64)  0           ['stage1_unit2_conv2[0][0]',
#                                                                   'add[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 80, 160, 64)  256        ['add_1[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 80, 160, 64)  0          ['stage2_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 82, 162, 64)  0          ['stage2_unit1_relu1[0][0]']
#  D)
#
#  stage2_unit1_conv1 (Conv2D)    (None, 40, 80, 128)  73728       ['zero_padding2d_6[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 40, 80, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 40, 80, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 42, 82, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 40, 80, 128)  147456      ['zero_padding2d_7[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 40, 80, 128)  8192        ['stage2_unit1_relu1[0][0]']
#
#  add_2 (Add)                    (None, 40, 80, 128)  0           ['stage2_unit1_conv2[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 40, 80, 128)  512        ['add_2[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 40, 80, 128)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 42, 82, 128)  0          ['stage2_unit2_relu1[0][0]']
#  D)
#
#  stage2_unit2_conv1 (Conv2D)    (None, 40, 80, 128)  147456      ['zero_padding2d_8[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 40, 80, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 40, 80, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 42, 82, 128)  0          ['stage2_unit2_relu2[0][0]']
#  D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 40, 80, 128)  147456      ['zero_padding2d_9[0][0]']
#
#  add_3 (Add)                    (None, 40, 80, 128)  0           ['stage2_unit2_conv2[0][0]',
#                                                                   'add_2[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 40, 80, 128)  512        ['add_3[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 40, 80, 128)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 42, 82, 128)  0          ['stage3_unit1_relu1[0][0]']
#  2D)
#
#  stage3_unit1_conv1 (Conv2D)    (None, 20, 40, 256)  294912      ['zero_padding2d_10[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 20, 40, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 20, 40, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 22, 42, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 20, 40, 256)  589824      ['zero_padding2d_11[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 20, 40, 256)  32768       ['stage3_unit1_relu1[0][0]']
#
#  add_4 (Add)                    (None, 20, 40, 256)  0           ['stage3_unit1_conv2[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 20, 40, 256)  1024       ['add_4[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 20, 40, 256)  0          ['stage3_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 22, 42, 256)  0          ['stage3_unit2_relu1[0][0]']
#  2D)
#
#  stage3_unit2_conv1 (Conv2D)    (None, 20, 40, 256)  589824      ['zero_padding2d_12[0][0]']
#  stage3_unit2_bn2 (BatchNormali  (None, 20, 40, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 20, 40, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 22, 42, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 20, 40, 256)  589824      ['zero_padding2d_13[0][0]']
#
#  add_5 (Add)                    (None, 20, 40, 256)  0           ['stage3_unit2_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 20, 40, 256)  1024       ['add_5[0][0]']
#  zation)
#
#  stage4_unit1_relu1 (Activation  (None, 20, 40, 256)  0          ['stage4_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 22, 42, 256)  0          ['stage4_unit1_relu1[0][0]']
#  2D)
#
#  stage4_unit1_conv1 (Conv2D)    (None, 10, 20, 512)  1179648     ['zero_padding2d_14[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 10, 20, 512)  2048       ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 10, 20, 512)  0          ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 12, 22, 512)  0          ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 10, 20, 512)  2359296     ['zero_padding2d_15[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 10, 20, 512)  131072      ['stage4_unit1_relu1[0][0]']
#
#  add_6 (Add)                    (None, 10, 20, 512)  0           ['stage4_unit1_conv2[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 10, 20, 512)  2048       ['add_6[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 10, 20, 512)  0          ['stage4_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 12, 22, 512)  0          ['stage4_unit2_relu1[0][0]']
#  2D)
#
#  stage4_unit2_conv1 (Conv2D)    (None, 10, 20, 512)  2359296     ['zero_padding2d_16[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 10, 20, 512)  2048       ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 10, 20, 512)  0          ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_17 (ZeroPadding  (None, 12, 22, 512)  0          ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 10, 20, 512)  2359296     ['zero_padding2d_17[0][0]']
#
#  add_7 (Add)                    (None, 10, 20, 512)  0           ['stage4_unit2_conv2[0][0]',
#                                                                   'add_6[0][0]']
#
#  bn1 (BatchNormalization)       (None, 10, 20, 512)  2048        ['add_7[0][0]']
#
#  relu1 (Activation)             (None, 10, 20, 512)  0           ['bn1[0][0]']
#
#  decoder_stage0_upsampling (UpS  (None, 20, 40, 512)  0          ['relu1[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 20, 40, 768)  0          ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 20, 40, 256)  1769472     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 20, 40, 256)  1024       ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 20, 40, 256)  0          ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 20, 40, 256)  589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 20, 40, 256)  1024       ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 20, 40, 256)  0          ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 40, 80, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 40, 80, 384)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 40, 80, 128)  442368      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 40, 80, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 40, 80, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 40, 80, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 40, 80, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 40, 80, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 80, 160, 128  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage2_concat (Concate  (None, 80, 160, 192  0          ['decoder_stage2_upsampling[0][0]
#  nate)                          )                                ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 80, 160, 64)  110592      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 80, 160, 64)  256        ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 80, 160, 64)  0          ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 80, 160, 64)  36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 80, 160, 64)  256        ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 80, 160, 64)  0          ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 160, 320, 64  0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage3_concat (Concate  (None, 160, 320, 12  0          ['decoder_stage3_upsampling[0][0]
#  nate)                          8)                               ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 160, 320, 32  36864       ['decoder_stage3_concat[0][0]']
#                                 )
#
#  decoder_stage3a_bn (BatchNorma  (None, 160, 320, 32  128        ['decoder_stage3a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3a_relu (Activati  (None, 160, 320, 32  0          ['decoder_stage3a_bn[0][0]']
#  on)                            )
#
#  decoder_stage3b_conv (Conv2D)  (None, 160, 320, 32  9216        ['decoder_stage3a_relu[0][0]']
#                                 )
#
#  decoder_stage3b_bn (BatchNorma  (None, 160, 320, 32  128        ['decoder_stage3b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3b_relu (Activati  (None, 160, 320, 32  0          ['decoder_stage3b_bn[0][0]']
#  on)                            )
#
#  decoder_stage4_upsampling (UpS  (None, 320, 640, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 320, 640, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 320, 640, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 320, 640, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 320, 640, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 320, 640, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 320, 640, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 320, 640, 1)  145         ['decoder_stage4b_relu[0][0]']
#
#  sigmoid (Activation)           (None, 320, 640, 1)  0           ['final_conv[0][0]']
#
# ==================================================================================================
# Total params: 14,340,570
# Trainable params: 14,330,644
# Non-trainable params: 9,926
# __________________________________________________________________________________________________

# %% [markdown]
# # Segmentation model training

# %%
def get_preprocessing(preprocessing_fn):    
    return A.Compose([A.Lambda(image=preprocessing_fn),])

class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return tuple(batch)
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    #augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    #augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
    data_choose = True
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('04_unet_training/best_model.h5', 
                                    save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]

# %%
# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=callbacks, 
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 2022-10-23 16:35:50.843694: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x398b4d10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-10-23 16:35:50.843735: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2022-10-23 16:35:50.843742: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (1): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2022-10-23 16:35:50.843747: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (2): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2022-10-23 16:35:50.843751: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (3): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2022-10-23 16:35:50.879682: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2022-10-23 16:35:51.764842: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 2022-10-23 16:35:58.170955: I tensorflow/stream_executor/cuda/cuda_dnn.cc:5025] Disabling cuDNN frontend for the following convolution:
#   input: {count: 16 feature_map_count: 64 spatial: 80 160  value_min: 0.000000 value_max: 0.000000 layout: BatchDepthYX}
#   filter: {output_feature_map_count: 64 input_feature_map_count: 64 layout: OutputInputYX shape: 3 3 }
#   {zero_padding: 1 1  pad_alignment: default filter_strides: 1 1  dilation_rates: 1 1 }
#   ... because it uses an identity activation.
# 2022-10-23 16:35:58.195592: I tensorflow/stream_executor/cuda/cuda_dnn.cc:5025] Disabling cuDNN frontend for the following convolution:
#   input: {count: 16 feature_map_count: 128 spatial: 40 80  value_min: 0.000000 value_max: 0.000000 layout: BatchDepthYX}
#   filter: {output_feature_map_count: 128 input_feature_map_count: 128 layout: OutputInputYX shape: 3 3 }
#   {zero_padding: 1 1  pad_alignment: default filter_strides: 1 1  dilation_rates: 1 1 }
#   ... because it uses an identity activation.
# 2022-10-23 16:35:58.210273: I tensorflow/stream_executor/cuda/cuda_dnn.cc:5025] Disabling cuDNN frontend for the following convolution:
#   input: {count: 16 feature_map_count: 256 spatial: 20 40  value_min: 0.000000 value_max: 0.000000 layout: BatchDepthYX}
#   filter: {output_feature_map_count: 256 input_feature_map_count: 256 layout: OutputInputYX shape: 3 3 }
#   {zero_padding: 1 1  pad_alignment: default filter_strides: 1 1  dilation_rates: 1 1 }
#   ... because it uses an identity activation.
# 2022-10-23 16:35:58.221881: I tensorflow/stream_executor/cuda/cuda_dnn.cc:5025] Disabling cuDNN frontend for the following convolution:
#   input: {count: 16 feature_map_count: 512 spatial: 10 20  value_min: 0.000000 value_max: 0.000000 layout: BatchDepthYX}
#   filter: {output_feature_map_count: 512 input_feature_map_count: 512 layout: OutputInputYX shape: 3 3 }
#   {zero_padding: 1 1  pad_alignment: default filter_strides: 1 1  dilation_rates: 1 1 }
#   ... because it uses an identity activation.
# 2022-10-23 16:35:58.281489: I tensorflow/stream_executor/cuda/cuda_dnn.cc:5025] Disabling cuDNN frontend for the following convolution:
#   input: {count: 16 feature_map_count: 16 spatial: 320 640  value_min: 0.000000 value_max: 0.000000 layout: BatchDepthYX}
#   filter: {output_feature_map_count: 1 input_feature_map_count: 16 layout: OutputInputYX shape: 3 3 }
#   {zero_padding: 1 1  pad_alignment: default filter_strides: 1 1  dilation_rates: 1 1 }
#   ... because it uses an identity activation.
# 2022-10-23 16:36:01.953783: I tensorflow/compiler/jit/xla_compilation_cache.cc:476] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2022-10-23 16:36:08.686749: I tensorflow/stream_executor/cuda/cuda_dnn.cc:5025] Disabling cuDNN frontend for the following convolution:
#   input: {count: 16 feature_map_count: 64 spatial: 80 160  value_min: 0.000000 value_max: 0.000000 layout: BatchDepthYX}
#   filter: {output_feature_map_count: 64 input_feature_map_count: 64 layout: OutputInputYX shape: 1 1 }
#   {zero_padding: 0 0  pad_alignment: default filter_strides: 1 1  dilation_rates: 1 1 }
#   ... because it uses an identity activation.
#  701/3104 [=====>........................] - ETA: 6:42 - loss: 0.2092 - iou_score: 0.9602 - f1-score: 0.9752

# %%
# !CUDA_VISIBLE_DEVICES=0,1 python3 04_training_unet.py
